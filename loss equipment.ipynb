# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("./datasets/russia_losses_equipment.csv", parse_dates=True)
df.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  25-02-2022    2        10           7    80  516               49    4
# 1  26-02-2022    3        27          26   146  706               49    4
# 2  27-02-2022    4        27          26   150  706               50    4
# 3  28-02-2022    5        29          29   150  816               74   21
# 4  01-03-2022    6        29          29   198  846               77   24
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
# 1            130         60      2           2                      0
# 2            130         60      2           2                      0
# 3            291         60      3           2                      5
# 4            305         60      3           2                      7
#
#    special equipment  mobile SRBM system
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN

# %% [markdown]
# let's make a visualization to see the losses the Russian War Machine has incurred over time. Since we are using time as a variable, it would be a good idea to use a line graph. Also, to avoid some potential issues, I am going to remove the "day" attribute and work only with the "date" index.

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20,9))
plt.title("Russian Equipment Losses")
plt.xlabel("Date")
plt.ylabel("Asset")
sns.lineplot(data=DataFrame.drop("day", axis=1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\91959\OneDrive\Desktop\russia ukairan war\loss equipment.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/91959/OneDrive/Desktop/russia%20ukairan%20war/loss%20equipment.ipynb#ch0000003?line=3'>4</a> plt.xlabel("Date")
#       <a href='vscode-notebook-cell:/c%3A/Users/91959/OneDrive/Desktop/russia%20ukairan%20war/loss%20equipment.ipynb#ch0000003?line=4'>5</a> plt.ylabel("Asset")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91959/OneDrive/Desktop/russia%20ukairan%20war/loss%20equipment.ipynb#ch0000003?line=5'>6</a> sns.lineplot(data=DataFrame.drop("day", axis=1))
#       <a href='vscode-notebook-cell:/c%3A/Users/91959/OneDrive/Desktop/russia%20ukairan%20war/loss%20equipment.ipynb#ch0000003?line=6'>7</a> plt.show()
#
# NameError: name 'DataFrame' is not defined

# %% [markdown]
# There are three bins that trend positively: fuel, tanks, and military auto. It could also be argued that fuel expenditures have a relationship with tank and military auto losses. Let's take a closer look at these three variables.

# %%
plt.figure(figsize=(20,9))

x_data = ["military auto", "APC"]

for vehicle in x_data:
    sns.lmplot(data=DataFrame, x=vehicle, y="tank")
plt.show()

# %% [markdown]
# Military auto losses have a large, positive trending relationship. At the static rate of 60 fuel tanks lost per day, this behavior is to be expected. The more fuel that is lost, the more likely it is to be that vehicle losses will incure due to lack of fuel and/or Ukranian acquisition.

# %%
plt.figure(figsize=(7,7))
DataFrame.sum().sort_values().plot(kind='pie',autopct=lambda p:'{:.2f}%\n({:.0f})'.format(p,(p/100)*(DataFrame.sum().sort_values().sum())))
plt.title('Destroyed Equepments')
# Out:
# Text(0.5, 1.0, 'Destroyed Equepments')
